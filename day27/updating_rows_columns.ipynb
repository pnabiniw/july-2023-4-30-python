# %%
people = {
    "first": ["Jon", "Jane", "Hary", "Ken"], 
    "last": ["abc", "xyz", "pqr", "def"],
    "email": ["jon@email.com", "jane@email.com", "hary@email.com", "ken@email.com"]
}

# %%
import pandas as pd
df = pd.DataFrame(people)
df
# Out:
#   first last           email
# 0   Jon  abc   jon@email.com
# 1  Jane  xyz  jane@email.com
# 2  Hary  pqr  hary@email.com
# 3   Ken  def   ken@email.com

# %%
df.columns = ["first_name", "last_name", "Email"]

# %%
df
# Out:
#   first_name last_name           Email
# 0        Jon       abc   jon@email.com
# 1       Jane       xyz  jane@email.com
# 2       Hary       pqr  hary@email.com
# 3        Ken       def   ken@email.com

# %%
df.coumns = [x.upper() for x in df.columns]
df
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_11592\4104365536.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.coumns = [x.upper() for x in df.columns]
#   first_name last_name           Email
# 0        Jon       abc   jon@email.com
# 1       Jane       xyz  jane@email.com
# 2       Hary       pqr  hary@email.com
# 3        Ken       def   ken@email.com

# %%
df.columns = [x.upper() for x in df.columns]
df
# Out:
#   FIRST_NAME LAST_NAME           EMAIL
# 0        Jon       abc   jon@email.com
# 1       Jane       xyz  jane@email.com
# 2       Hary       pqr  hary@email.com
# 3        Ken       def   ken@email.com

# %%
df.columns = df.columns.str.replace('_', " ")
df
# Out:
#   FIRST NAME LAST NAME           EMAIL
# 0        Jon       abc   jon@email.com
# 1       Jane       xyz  jane@email.com
# 2       Hary       pqr  hary@email.com
# 3        Ken       def   ken@email.com

# %%
df.columns = [x.lower() for x in df.columns]
df
# Out:
#   first name last name           email
# 0        Jon       abc   jon@email.com
# 1       Jane       xyz  jane@email.com
# 2       Hary       pqr  hary@email.com
# 3        Ken       def   ken@email.com

# %%
df.columns = df.columns.str.replace(' ', "_")
df
# Out:
#   first_name last_name           email
# 0        Jon       abc   jon@email.com
# 1       Jane       xyz  jane@email.com
# 2       Hary       pqr  hary@email.com
# 3        Ken       def   ken@email.com

# %%
df.rename(columns={"email": "Email"})
# Out:
#   first_name last_name           Email
# 0        Jon       abc   jon@email.com
# 1       Jane       xyz  jane@email.com
# 2       Hary       pqr  hary@email.com
# 3        Ken       def   ken@email.com

# %%
df
# Out:
#   first_name last_name           email
# 0        Jon       abc   jon@email.com
# 1       Jane       xyz  jane@email.com
# 2       Hary       pqr  hary@email.com
# 3        Ken       def   ken@email.com

# %%
df.rename(columns={"email": "Email"}, inplace=True)
df
# Out:
#   first_name last_name           Email
# 0        Jon       abc   jon@email.com
# 1       Jane       xyz  jane@email.com
# 2       Hary       pqr  hary@email.com
# 3        Ken       def   ken@email.com

# %%
df.loc[2] = ["hary", "potter", "hp@email.com"]
df
# Out:
#   first_name last_name           Email
# 0        Jon       abc   jon@email.com
# 1       Jane       xyz  jane@email.com
# 2       hary    potter    hp@email.com
# 3        Ken       def   ken@email.com

# %%
df.loc[2, ["first_name", "last_name"]] = ["Hary", "Potter"]
df
# Out:
#   first_name last_name           Email
# 0        Jon       abc   jon@email.com
# 1       Jane       xyz  jane@email.com
# 2       Hary    Potter    hp@email.com
# 3        Ken       def   ken@email.com

# %%
df.loc[2, "Email"] = "harrypotter@email.com"
df
# Out:
#   first_name last_name                  Email
# 0        Jon       abc          jon@email.com
# 1       Jane       xyz         jane@email.com
# 2       Hary    Potter  harrypotter@email.com
# 3        Ken       def          ken@email.com

# %%
filt = (df["Email"] == "harrypotter@email.com")
df.loc[filt, "last_name"] = "potter"
df
# Out:
#   first_name last_name                  Email
# 0        Jon       abc          jon@email.com
# 1       Jane       xyz         jane@email.com
# 2       Hary    potter  harrypotter@email.com
# 3        Ken       def          ken@email.com

# %%
df.loc[3, "last_name"] = "DEF"
df
# Out:
#   first_name last_name                  Email
# 0        Jon       abc          jon@email.com
# 1       Jane       xyz         jane@email.com
# 2       Hary    potter  harrypotter@email.com
# 3        Ken       DEF          ken@email.com

# %%
def to_upper(email):
    return email.upper()
df["Email"] = df["Email"].apply(to_upper)
df
# Out:
#   first_name last_name                  Email
# 0        Jon       abc          JON@EMAIL.COM
# 1       Jane       xyz         JANE@EMAIL.COM
# 2       Hary    potter  HARRYPOTTER@EMAIL.COM
# 3        Ken       DEF          KEN@EMAIL.COM

# %%
df["Email"] = df["Email"].apply(lambda x: x.lower())
df
# Out:
#   first_name last_name                  Email
# 0        Jon       abc          jon@email.com
# 1       Jane       xyz         jane@email.com
# 2       Hary    potter  harrypotter@email.com
# 3        Ken       DEF          ken@email.com

# %%
df["first_name"] = df["first_name"].replace({"Jon": "John", "Hary": "Harry"})
df
# Out:
#   first_name last_name                  Email
# 0       John       abc          jon@email.com
# 1       Jane       xyz         jane@email.com
# 2      Harry    potter  harrypotter@email.com
# 3        Ken       DEF          ken@email.com

# %%
# Adding / Removing rows and columns from a dataframe
df['first_name'] + " " + df["last_name"]
# Out:
# 0        John abc
# 1        Jane xyz
# 2    Harry potter
# 3         Ken DEF
# dtype: object

# %%
df["full_name"] = df['first_name'] + " " + df["last_name"]
df
# Out:
#   first_name last_name                  Email     full_name
# 0       John       abc          jon@email.com      John abc
# 1       Jane       xyz         jane@email.com      Jane xyz
# 2      Harry    potter  harrypotter@email.com  Harry potter
# 3        Ken       DEF          ken@email.com       Ken DEF

# %%
df.drop(columns=["full_name"])
# Out:
#   first_name last_name                  Email
# 0       John       abc          jon@email.com
# 1       Jane       xyz         jane@email.com
# 2      Harry    potter  harrypotter@email.com
# 3        Ken       DEF          ken@email.com

# %%
df
# Out:
#   first_name last_name                  Email     full_name
# 0       John       abc          jon@email.com      John abc
# 1       Jane       xyz         jane@email.com      Jane xyz
# 2      Harry    potter  harrypotter@email.com  Harry potter
# 3        Ken       DEF          ken@email.com       Ken DEF

# %%
df.drop(columns=["full_name"], inplace=True)
df
# Out:
#   first_name last_name                  Email
# 0       John       abc          jon@email.com
# 1       Jane       xyz         jane@email.com
# 2      Harry    potter  harrypotter@email.com
# 3        Ken       DEF          ken@email.com

# %%
df
# Out:
#   first_name last_name                  Email
# 0       John       abc          jon@email.com
# 1       Jane       xyz         jane@email.com
# 2      Harry    potter  harrypotter@email.com
# 3        Ken       DEF          ken@email.com

# %%
people = {"first_name": ["Bruce", "Robin"], "last_name": ["Wayne", "Roger"], "Email": ["bruce@email.com", "robin@email.com"]}
df2 = pd.DataFrame(people)
df.loc[3] = ["Bruce", "Wyane", "bruce@email.com"]
# df = df.append(df2, ignore_index=True)
df
# Out:
#   first_name last_name                  Email
# 0       John       abc          jon@email.com
# 1       Jane       xyz         jane@email.com
# 2      Harry    potter  harrypotter@email.com
# 3      Bruce     Wyane        bruce@email.com

# %%
df.drop(index=3, inplace=True)
df
# Out:
#   first_name last_name                  Email
# 0       John       abc          jon@email.com
# 1       Jane       xyz         jane@email.com
# 2      Harry    potter  harrypotter@email.com

# %%
filt = (df['Email'] == "jane@email.com")
df.drop(index=df[filt].index, inplace=True)
df
# Out:
#   first_name last_name                  Email
# 0       John       abc          jon@email.com
# 2      Harry    potter  harrypotter@email.com

# %%
df.loc[2, "Email"] = "harrypotter@email.com"
df
# Out:
#   first_name last_name                  Email
# 0       John       abc          jon@email.com
# 2      Harry    potter  harrypotter@email.com

# %%
df.sort_values(by='last_name', ascending=False, inplace=True)
df
# Out:
#   first_name last_name                  Email
# 2      Harry    potter  harrypotter@email.com
# 0       John       abc          jon@email.com

# %%
df.sort_values(by=["last_name", "first_name"], ascending=False, inplace=True)
df
# Out:
#   first_name last_name                  Email
# 2      Harry    potter  harrypotter@email.com
# 0       John       abc          jon@email.com

# %%
df.loc[0, "last_name"] = "potter"
df
# Out:
#   first_name last_name                  Email
# 2      Harry    potter  harrypotter@email.com
# 0       John    potter          jon@email.com

# %%
df.sort_values(by=["last_name", "first_name"], ascending=False, inplace=True)
df
# Out:
#   first_name last_name                  Email
# 0       John    potter          jon@email.com
# 2      Harry    potter  harrypotter@email.com
